# %% [markdown]
# # Approximation of the cost of the centralized and decentralized systems for a finite N in the SIR model with vaccinations

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import scipy.io as sio

from mpl_toolkits.mplot3d import Axes3D
#import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
#import numpy

# %% [markdown]
# The function below computes the mean-field equilibrium

# %%
def mf_equilibrium():
    """
    We compute the mean-field equilibrium as a fixed-point problem. The algorithm stops if 
    after n_loops_max the fixed point has not been found.
    """
    count2=0; n_loops_max=5000
    thr_pl0=-1;
    best_pol=np.zeros(TimeHorizon+1);
    vs = np.zeros(TimeHorizon+1); vi = np.zeros(TimeHorizon+1)
    
    def best_response_threshold(thr_mass):
        x_S = np.zeros(TimeHorizon+1); x_I = np.zeros(TimeHorizon+1);
        policy = np.zeros(TimeHorizon+1);
        x_S[0]=S0; x_I[0]=I0;
        for i in range(TimeHorizon):
            if i<thr_mass:
                policy[i]=theta;
            else:
                policy[i]=vac_min;
            x_S[i+1] = x_S[i]+(-gamma*x_I[i]*x_S[i] - policy[i]*x_S[i])/C;
            x_I[i+1] = x_I[i]+(gamma*x_S[i] - rho)*x_I[i]/C;

        for t_ in range(TimeHorizon,0,-1):
            if c_V - vs[t_] < 0:
                best_pol[t_-1]=theta;
                p_s_s=1 - 1.*gamma*x_I[t_-1]/C - 1.*theta/C;
                p_s_i=1.*gamma*x_I[t_-1]/C; 
                vs[t_-1]= theta * c_V /C + p_s_s * vs[t_] + p_s_i * vi[t_];
            else:
                best_pol[t_-1]=vac_min;
                p_s_s=1 - 1.*gamma*x_I[t_-1]/C - vac_min/C;
                p_s_i=gamma*x_I[t_-1]/C; 
                vs[t_-1]= vac_min * c_V/C + p_s_s * vs[t_] + p_s_i * vi[t_];   
            p_i_i=1-rho/C; 
            vi[t_-1] = c_I/C + p_i_i * vi[t_];  
        
        thr=0;
        for i in range(TimeHorizon+1):
            if vs[i]<c_V:
                thr_pl0=i;
                break;
        return thr_pl0
    
    # Now we first find a threshold such that the BR is smaller than the threshold
    thr_mass=0
    while best_response_threshold(thr_mass) > thr_mass:
        thr_mass = max(1,thr_mass*2)
        
    # Then we apply a dicotomic search 
    thr_mass = int(thr_mass/2)
    deltaThreshold=int(np.ceil(thr_mass/2))
    for i in range(20):
        br_threshold = best_response_threshold(thr_mass)
        if br_threshold > thr_mass:
            thr_mass += deltaThreshold
        elif br_threshold < thr_mass:
            thr_mass -= deltaThreshold
        deltaThreshold = min(thr_mass,int(np.ceil(deltaThreshold/2)))
        if deltaThreshold <= 1:
            break
        
    cost_mfe=vs[0]*S0+vi[0]*I0;
    print('threshold=',thr_mass,end=' ')
    return cost_mfe;

#for I0 in [1e-3,1e-9,1e-12,1e-25,1e-28]:
#    mf_equilibrium()

# %% [markdown]
# The function above computes the mean-field optimum

# %%
def mf_optimum():
    """
    This method uses a divide and conquer approach to compute the minimum value. 
    It assumes that the optimal policy is a bang-bang policy with a unique jump time"""
    my_policy=np.zeros(TimeHorizon+1);
    j=0;
    v=np.zeros(TimeHorizon+1);
    x_S=np.zeros(TimeHorizon+1);
    x_I=np.zeros(TimeHorizon+1);
    
    def compute_cost(t_critical):
        x_S[0]=S0; x_I[0]=I0;
        if v[t_critical] > 0: return
        for i in range(TimeHorizon):
            my_policy[i] = theta if i<t_critical else vac_min
            x_S[i+1] = x_S[i]+(-gamma*x_I[i]*x_S[i] - my_policy[i]*x_S[i])/C;
            x_I[i+1] = x_I[i]+(gamma*x_I[i]*x_S[i] - rho*x_I[i])/C;    

        v[t_critical] = sum(1.*c_I*x_I/C+1.*c_V*x_S*my_policy/C);    
    
    t_critical = int(C/2)
    deltaT = int(C/4)
    for i in range(20):
        for t in [t_critical,t_critical+1]:
            compute_cost(t)
        if v[t_critical+1]>v[t_critical]: 
            t_critical -= deltaT
        else: 
            t_critical += deltaT
        deltaT = min(t_critical,int(np.ceil(deltaT/2)))
        if deltaT == 0:
            break
#    plt.plot(x_S)  
#    plt.semilogy(x_I)
#    #plt.plot(x_I)
#    plt.plot([0,10000],[rho/gamma,rho/gamma],'--')
#    plt.legend(['m_S','m_I'])

        
    cost_opt=v[t_critical]
    mypos=t_critical
    return cost_opt; 

#for I0 in [1e-3,1e-4,1e-5]:
#    mf_optimum()

# %%
# system parameters
gamma = 73.0      # infection rate
rho = 36.5        # recovery rate
vac_min = 0.0     # minimum vaccination rate
theta = 10.0      # maximum vaccination rate
T = 1             # time horizon

# costs
c_V = 0.5       # cost per unit time of vaccination
c_I = 36.5         # cost per unit time of infection

# uniformization constant
C=int(100000)
TimeHorizon = int(T*C)

N=100
mfe_cost = []; mfopt_cost = []
for s0 in range(1,N):
    mfe_cost_v = []; mfopt_cost_v = []
    for i0 in range(1,N):
        print('computing for (s,i)=',s0,i0,end='...')
        if N-s0-i0>0: 
            I0=i0/N; S0=s0/N
            val_mfe_cost = mf_equilibrium()
            print('mfe done',end='...')
            val_mfopt_cost = mf_optimum()
            print('mfopt done')
        else:
            val_mfe_cost = 0
            val_mfopt_cost = -1
        mfe_cost_v.append(val_mfe_cost)
        mfopt_cost_v.append(val_mfopt_cost)
    mfe_cost.append(mfe_cost_v); 
    mfopt_cost.append(mfopt_cost_v)
    
mat_mfe_cost=np.array([np.array(xi) for xi in mfe_cost])
mat_mfopt_cost=np.array([np.array(xi) for xi in mfopt_cost])
sio.savemat('data/mfe_cost_N100.mat', {'mfe_cost':mfe_cost})
sio.savemat('data/mfopt_cost_N100.mat', {'mfopt_cost':mfopt_cost})
# Out:
# computing for (s,i)= 1 1...equi done
# computing for (s,i)= 1 2...equi done
# computing for (s,i)= 1 3...equi done
# computing for (s,i)= 1 4...equi done
# computing for (s,i)= 1 5...equi done
# computing for (s,i)= 1 6...equi done
# computing for (s,i)= 1 7...equi done
# computing for (s,i)= 1 8...equi done
# computing for (s,i)= 1 9...equi done
# computing for (s,i)= 1 10...equi done
# computing for (s,i)= 1 11...equi done
# computing for (s,i)= 1 12...equi done
# computing for (s,i)= 1 13...equi done
# computing for (s,i)= 1 14...equi done
# computing for (s,i)= 1 15...equi done
# computing for (s,i)= 1 16...equi done
# computing for (s,i)= 1 17...equi done
# computing for (s,i)= 1 18...equi done
# computing for (s,i)= 1 19...equi done
# computing for (s,i)= 1 20...equi done
# computing for (s,i)= 1 21...equi done
# computing for (s,i)= 1 22...equi done
# computing for (s,i)= 1 23...equi done
# computing for (s,i)= 1 24...equi done
# computing for (s,i)= 1 25...equi done
# computing for (s,i)= 1 26...equi done
# computing for (s,i)= 1 27...equi done
# computing for (s,i)= 1 28...equi done
# computing for (s,i)= 1 29...equi done
# computing for (s,i)= 1 30...equi done
# computing for (s,i)= 1 31...equi done
# computing for (s,i)= 1 32...equi done
# computing for (s,i)= 1 33...equi done
# computing for (s,i)= 1 34...equi done
# computing for (s,i)= 1 35...equi done
# computing for (s,i)= 1 36...equi done
# computing for (s,i)= 1 37...equi done
# computing for (s,i)= 1 38...equi done
# computing for (s,i)= 1 39...equi done
# computing for (s,i)= 1 40...equi done
# computing for (s,i)= 1 41...equi done
# computing for (s,i)= 1 42...equi done
# computing for (s,i)= 1 43...equi done
# computing for (s,i)= 1 44...equi done
# computing for (s,i)= 1 45...equi done
# computing for (s,i)= 1 46...equi done
# computing for (s,i)= 1 47...equi done
# computing for (s,i)= 1 48...equi done
# computing for (s,i)= 1 49...equi done
# computing for (s,i)= 1 50...equi done
# computing for (s,i)= 1 51...equi done
# computing for (s,i)= 1 52...equi done
# computing for (s,i)= 1 53...equi done
# computing for (s,i)= 1 54...equi done
# computing for (s,i)= 1 55...equi done
# computing for (s,i)= 1 56...equi done
# computing for (s,i)= 1 57...equi done
# computing for (s,i)= 1 58...equi done
# computing for (s,i)= 1 59...equi done
# computing for (s,i)= 1 60...equi done
# computing for (s,i)= 1 61...equi done
# computing for (s,i)= 1 62...equi done
# computing for (s,i)= 1 63...equi done
# computing for (s,i)= 1 64...equi done
# computing for (s,i)= 1 65...equi done
# computing for (s,i)= 1 66...equi done
# computing for (s,i)= 1 67...equi done
# computing for (s,i)= 1 68...equi done
# computing for (s,i)= 1 69...equi done
# computing for (s,i)= 1 70...equi done
# computing for (s,i)= 1 71...equi done
# computing for (s,i)= 1 72...equi done
# computing for (s,i)= 1 73...equi done
# computing for (s,i)= 1 74...equi done
# computing for (s,i)= 1 75...equi done
# computing for (s,i)= 1 76...equi done
# computing for (s,i)= 1 77...equi done
# computing for (s,i)= 1 78...equi done
# computing for (s,i)= 1 79...equi done
# computing for (s,i)= 1 80...equi done
# computing for (s,i)= 1 81...equi done
# computing for (s,i)= 1 82...equi done
# computing for (s,i)= 1 83...equi done
# computing for (s,i)= 1 84...equi done
# computing for (s,i)= 1 85...equi done
# computing for (s,i)= 1 86...equi done
# computing for (s,i)= 1 87...equi done
# computing for (s,i)= 1 88...equi done
# computing for (s,i)= 1 89...equi done
# computing for (s,i)= 1 90...equi done
# computing for (s,i)= 1 91...equi done
# computing for (s,i)= 1 92...equi done
# computing for (s,i)= 1 93...equi done
# computing for (s,i)= 1 94...equi done
# computing for (s,i)= 1 95...equi done
# computing for (s,i)= 1 96...equi done
# computing for (s,i)= 1 97...equi done
# computing for (s,i)= 1 98...equi done
# computing for (s,i)= 1 99...computing for (s,i)= 2 1...equi done
# computing for (s,i)= 2 2...equi done
# computing for (s,i)= 2 3...equi done
# computing for (s,i)= 2 4...equi done
# computing for (s,i)= 2 5...equi done
# computing for (s,i)= 2 6...equi done
# computing for (s,i)= 2 7...equi done
# computing for (s,i)= 2 8...equi done
# computing for (s,i)= 2 9...equi done
# computing for (s,i)= 2 10...equi done
# computing for (s,i)= 2 11...equi done
# computing for (s,i)= 2 12...equi done
# computing for (s,i)= 2 13...equi done
# computing for (s,i)= 2 14...equi done
# computing for (s,i)= 2 15...equi done
# computing for (s,i)= 2 16...equi done
# computing for (s,i)= 2 17...equi done
# computing for (s,i)= 2 18...equi done
# computing for (s,i)= 2 19...equi done
# computing for (s,i)= 2 20...equi done
# computing for (s,i)= 2 21...equi done
# computing for (s,i)= 2 22...equi done
# computing for (s,i)= 2 23...equi done
# computing for (s,i)= 2 24...equi done
# computing for (s,i)= 2 25...equi done
# computing for (s,i)= 2 26...equi done
# computing for (s,i)= 2 27...equi done
# computing for (s,i)= 2 28...equi done
# computing for (s,i)= 2 29...equi done
# computing for (s,i)= 2 30...equi done
# computing for (s,i)= 2 31...equi done
# computing for (s,i)= 2 32...equi done
# computing for (s,i)= 2 33...equi done
# computing for (s,i)= 2 34...equi done
# computing for (s,i)= 2 35...equi done
# computing for (s,i)= 2 36...equi done
# computing for (s,i)= 2 37...equi done
# computing for (s,i)= 2 38...equi done
# computing for (s,i)= 2 39...equi done
# computing for (s,i)= 2 40...equi done
# computing for (s,i)= 2 41...equi done
# computing for (s,i)= 2 42...equi done
# computing for (s,i)= 2 43...equi done
# computing for (s,i)= 2 44...equi done
# computing for (s,i)= 2 45...equi done
# computing for (s,i)= 2 46...equi done
# computing for (s,i)= 2 47...equi done
# computing for (s,i)= 2 48...equi done
# computing for (s,i)= 2 49...equi done
# computing for (s,i)= 2 50...equi done
# computing for (s,i)= 2 51...equi done
# computing for (s,i)= 2 52...equi done
# computing for (s,i)= 2 53...equi done
# computing for (s,i)= 2 54...equi done
# computing for (s,i)= 2 55...equi done
# computing for (s,i)= 2 56...equi done
# computing for (s,i)= 2 57...equi done
# computing for (s,i)= 2 58...equi done
# computing for (s,i)= 2 59...equi done
# computing for (s,i)= 2 60...equi done
# computing for (s,i)= 2 61...equi done
# computing for (s,i)= 2 62...equi done
# computing for (s,i)= 2 63...equi done
# computing for (s,i)= 2 64...equi done
# computing for (s,i)= 2 65...equi done
# computing for (s,i)= 2 66...equi done
# computing for (s,i)= 2 67...equi done
# computing for (s,i)= 2 68...equi done
# computing for (s,i)= 2 69...equi done
# computing for (s,i)= 2 70...equi done
# computing for (s,i)= 2 71...equi done
# computing for (s,i)= 2 72...equi done
# computing for (s,i)= 2 73...equi done
# computing for (s,i)= 2 74...equi done
# computing for (s,i)= 2 75...equi done
# computing for (s,i)= 2 76...equi done
# computing for (s,i)= 2 77...equi done
# computing for (s,i)= 2 78...equi done
# computing for (s,i)= 2 79...equi done
# computing for (s,i)= 2 80...equi done
# computing for (s,i)= 2 81...equi done
# computing for (s,i)= 2 82...equi done
# computing for (s,i)= 2 83...equi done
# computing for (s,i)= 2 84...equi done
# computing for (s,i)= 2 85...equi done
# computing for (s,i)= 2 86...equi done
# computing for (s,i)= 2 87...equi done
# computing for (s,i)= 2 88...equi done
# computing for (s,i)= 2 89...equi done
# computing for (s,i)= 2 90...equi done
# computing for (s,i)= 2 91...equi done
# computing for (s,i)= 2 92...equi done
# computing for (s,i)= 2 93...equi done
# computing for (s,i)= 2 94...equi done
# computing for (s,i)= 2 95...equi done
# computing for (s,i)= 2 96...equi done
# computing for (s,i)= 2 97...equi done
# computing for (s,i)= 2 98...computing for (s,i)= 2 99...computing for (s,i)= 3 1...equi done
# computing for (s,i)= 3 2...equi done
# computing for (s,i)= 3 3...equi done
# computing for (s,i)= 3 4...equi done
# computing for (s,i)= 3 5...equi done
# computing for (s,i)= 3 6...equi done
# computing for (s,i)= 3 7...equi done
# computing for (s,i)= 3 8...equi done
# computing for (s,i)= 3 9...equi done
# computing for (s,i)= 3 10...equi done
# computing for (s,i)= 3 11...equi done
# computing for (s,i)= 3 12...equi done
# computing for (s,i)= 3 13...equi done
# computing for (s,i)= 3 14...equi done
# computing for (s,i)= 3 15...equi done
# computing for (s,i)= 3 16...equi done
# computing for (s,i)= 3 17...equi done
# computing for (s,i)= 3 18...equi done
# computing for (s,i)= 3 19...equi done
# computing for (s,i)= 3 20...equi done
# computing for (s,i)= 3 21...equi done
# computing for (s,i)= 3 22...equi done
# computing for (s,i)= 3 23...equi done
# computing for (s,i)= 3 24...equi done
# computing for (s,i)= 3 25...equi done
# computing for (s,i)= 3 26...equi done
# computing for (s,i)= 3 27...equi done
# computing for (s,i)= 3 28...equi done
# computing for (s,i)= 3 29...equi done
# computing for (s,i)= 3 30...equi done
# computing for (s,i)= 3 31...equi done
# computing for (s,i)= 3 32...equi done
# computing for (s,i)= 3 33...equi done
# computing for (s,i)= 3 34...equi done
# computing for (s,i)= 3 35...equi done
# computing for (s,i)= 3 36...equi done
# computing for (s,i)= 3 37...equi done
# computing for (s,i)= 3 38...equi done
# computing for (s,i)= 3 39...equi done
# computing for (s,i)= 3 40...equi done
# computing for (s,i)= 3 41...equi done
# computing for (s,i)= 3 42...equi done
# computing for (s,i)= 3 43...equi done
# computing for (s,i)= 3 44...equi done
# computing for (s,i)= 3 45...equi done
# computing for (s,i)= 3 46...equi done
# computing for (s,i)= 3 47...equi done
# computing for (s,i)= 3 48...equi done
# computing for (s,i)= 3 49...equi done
# computing for (s,i)= 3 50...equi done
# computing for (s,i)= 3 51...equi done
# computing for (s,i)= 3 52...equi done
# computing for (s,i)= 3 53...equi done
# computing for (s,i)= 3 54...equi done
# computing for (s,i)= 3 55...equi done
# computing for (s,i)= 3 56...equi done
# computing for (s,i)= 3 57...equi done
# computing for (s,i)= 3 58...equi done
# computing for (s,i)= 3 59...equi done
# computing for (s,i)= 3 60...equi done
# computing for (s,i)= 3 61...equi done
# computing for (s,i)= 3 62...equi done
# computing for (s,i)= 3 63...equi done
# computing for (s,i)= 3 64...equi done
# computing for (s,i)= 3 65...equi done
# computing for (s,i)= 3 66...equi done
# computing for (s,i)= 3 67...equi done
# computing for (s,i)= 3 68...equi done
# computing for (s,i)= 3 69...equi done
# computing for (s,i)= 3 70...equi done
# computing for (s,i)= 3 71...equi done
# computing for (s,i)= 3 72...equi done
# computing for (s,i)= 3 73...equi done
# computing for (s,i)= 3 74...equi done
# computing for (s,i)= 3 75...equi done
# computing for (s,i)= 3 76...equi done
# computing for (s,i)= 3 77...equi done
# computing for (s,i)= 3 78...equi done
# computing for (s,i)= 3 79...equi done
# computing for (s,i)= 3 80...equi done
# computing for (s,i)= 3 81...equi done
# computing for (s,i)= 3 82...equi done
# computing for (s,i)= 3 83...equi done
# computing for (s,i)= 3 84...equi done
# computing for (s,i)= 3 85...equi done
# computing for (s,i)= 3 86...equi done
# computing for (s,i)= 3 87...equi done
# computing for (s,i)= 3 88...equi done
# computing for (s,i)= 3 89...equi done
# computing for (s,i)= 3 90...equi done
# computing for (s,i)= 3 91...equi done
# computing for (s,i)= 3 92...equi done
# computing for (s,i)= 3 93...equi done
# computing for (s,i)= 3 94...equi done
# computing for (s,i)= 3 95...equi done
# computing for (s,i)= 3 96...equi done
# computing for (s,i)= 3 97...computing for (s,i)= 3 98...computing for (s,i)= 3 99...computing for (s,i)= 4 1...equi done
# computing for (s,i)= 4 2...equi done
# computing for (s,i)= 4 3...equi done
# computing for (s,i)= 4 4...equi done
# computing for (s,i)= 4 5...equi done
# computing for (s,i)= 4 6...equi done
# computing for (s,i)= 4 7...equi done
# computing for (s,i)= 4 8...equi done
# computing for (s,i)= 4 9...equi done
# computing for (s,i)= 4 10...equi done
# computing for (s,i)= 4 11...equi done
# computing for (s,i)= 4 12...equi done
# computing for (s,i)= 4 13...equi done
# computing for (s,i)= 4 14...equi done
# computing for (s,i)= 4 15...equi done
# computing for (s,i)= 4 16...equi done
# computing for (s,i)= 4 17...equi done
# computing for (s,i)= 4 18...equi done
# computing for (s,i)= 4 19...equi done
# computing for (s,i)= 4 20...equi done
# computing for (s,i)= 4 21...equi done
# computing for (s,i)= 4 22...equi done
# computing for (s,i)= 4 23...equi done
# computing for (s,i)= 4 24...equi done
# computing for (s,i)= 4 25...equi done
# computing for (s,i)= 4 26...equi done
# computing for (s,i)= 4 27...equi done
# computing for (s,i)= 4 28...equi done
# computing for (s,i)= 4 29...equi done
# computing for (s,i)= 4 30...equi done
# computing for (s,i)= 4 31...equi done
# computing for (s,i)= 4 32...equi done
# computing for (s,i)= 4 33...equi done
# computing for (s,i)= 4 34...equi done
# computing for (s,i)= 4 35...equi done
# computing for (s,i)= 4 36...equi done
# computing for (s,i)= 4 37...equi done
# computing for (s,i)= 4 38...equi done
# computing for (s,i)= 4 39...equi done
# computing for (s,i)= 4 40...equi done
# computing for (s,i)= 4 41...equi done
# computing for (s,i)= 4 42...equi done
# computing for (s,i)= 4 43...equi done
# computing for (s,i)= 4 44...equi done
# computing for (s,i)= 4 45...equi done
# computing for (s,i)= 4 46...equi done
# computing for (s,i)= 4 47...equi done
# computing for (s,i)= 4 48...equi done
# computing for (s,i)= 4 49...equi done
# computing for (s,i)= 4 50...equi done
# computing for (s,i)= 4 51...equi done
# computing for (s,i)= 4 52...equi done
# computing for (s,i)= 4 53...equi done
# computing for (s,i)= 4 54...equi done
# computing for (s,i)= 4 55...equi done
# computing for (s,i)= 4 56...equi done
# computing for (s,i)= 4 57...equi done
# computing for (s,i)= 4 58...equi done
# computing for (s,i)= 4 59...equi done
# computing for (s,i)= 4 60...equi done
# computing for (s,i)= 4 61...equi done
# computing for (s,i)= 4 62...equi done
# computing for (s,i)= 4 63...equi done
# computing for (s,i)= 4 64...equi done
# computing for (s,i)= 4 65...equi done
# computing for (s,i)= 4 66...equi done
# computing for (s,i)= 4 67...equi done
# computing for (s,i)= 4 68...equi done
# computing for (s,i)= 4 69...equi done
# computing for (s,i)= 4 70...equi done
# computing for (s,i)= 4 71...equi done
# computing for (s,i)= 4 72...equi done
# computing for (s,i)= 4 73...equi done
# computing for (s,i)= 4 74...equi done
# computing for (s,i)= 4 75...equi done
# computing for (s,i)= 4 76...equi done
# computing for (s,i)= 4 77...equi done
# computing for (s,i)= 4 78...equi done
# computing for (s,i)= 4 79...equi done
# computing for (s,i)= 4 80...equi done
# computing for (s,i)= 4 81...equi done
# computing for (s,i)= 4 82...equi done
# computing for (s,i)= 4 83...equi done
# computing for (s,i)= 4 84...equi done
# computing for (s,i)= 4 85...equi done
# computing for (s,i)= 4 86...equi done
# computing for (s,i)= 4 87...equi done
# computing for (s,i)= 4 88...equi done
# computing for (s,i)= 4 89...equi done
# computing for (s,i)= 4 90...equi done
# computing for (s,i)= 4 91...equi done
# computing for (s,i)= 4 92...equi done
# computing for (s,i)= 4 93...equi done
# computing for (s,i)= 4 94...equi done
# computing for (s,i)= 4 95...equi done
# computing for (s,i)= 4 96...computing for (s,i)= 4 97...computing for (s,i)= 4 98...computing for (s,i)= 4 99...computing for (s,i)= 5 1...equi done
# computing for (s,i)= 5 2...equi done
# computing for (s,i)= 5 3...equi done
# computing for (s,i)= 5 4...equi done
# computing for (s,i)= 5 5...equi done
# computing for (s,i)= 5 6...equi done
# computing for (s,i)= 5 7...equi done
# computing for (s,i)= 5 8...equi done
# computing for (s,i)= 5 9...equi done
# computing for (s,i)= 5 10...equi done
# computing for (s,i)= 5 11...equi done
# computing for (s,i)= 5 12...equi done
# computing for (s,i)= 5 13...equi done
# computing for (s,i)= 5 14...equi done
# computing for (s,i)= 5 15...equi done
# computing for (s,i)= 5 16...equi done
# computing for (s,i)= 5 17...equi done
# computing for (s,i)= 5 18...equi done
# computing for (s,i)= 5 19...equi done
# computing for (s,i)= 5 20...equi done
# computing for (s,i)= 5 21...equi done
# computing for (s,i)= 5 22...equi done
# computing for (s,i)= 5 23...equi done
# computing for (s,i)= 5 24...equi done
# computing for (s,i)= 5 25...equi done
# computing for (s,i)= 5 26...equi done
# computing for (s,i)= 5 27...equi done
# computing for (s,i)= 5 28...equi done
# computing for (s,i)= 5 29...equi done
# computing for (s,i)= 5 30...equi done
# computing for (s,i)= 5 31...equi done
# computing for (s,i)= 5 32...equi done
# computing for (s,i)= 5 33...equi done
# computing for (s,i)= 5 34...equi done
# computing for (s,i)= 5 35...equi done
# computing for (s,i)= 5 36...equi done
# computing for (s,i)= 5 37...equi done
# computing for (s,i)= 5 38...equi done
# computing for (s,i)= 5 39...equi done
# computing for (s,i)= 5 40...equi done
# computing for (s,i)= 5 41...equi done
# computing for (s,i)= 5 42...equi done
# computing for (s,i)= 5 43...equi done
# computing for (s,i)= 5 44...equi done
# computing for (s,i)= 5 45...equi done
# computing for (s,i)= 5 46...equi done
# computing for (s,i)= 5 47...equi done
# computing for (s,i)= 5 48...equi done
# computing for (s,i)= 5 49...equi done
# computing for (s,i)= 5 50...equi done
# computing for (s,i)= 5 51...equi done
# computing for (s,i)= 5 52...equi done
# computing for (s,i)= 5 53...equi done
# computing for (s,i)= 5 54...equi done
# computing for (s,i)= 5 55...equi done
# computing for (s,i)= 5 56...equi done
# computing for (s,i)= 5 57...equi done
# computing for (s,i)= 5 58...equi done
# computing for (s,i)= 5 59...equi done
# computing for (s,i)= 5 60...equi done
# computing for (s,i)= 5 61...equi done
# computing for (s,i)= 5 62...equi done
# computing for (s,i)= 5 63...equi done
# computing for (s,i)= 5 64...equi done
# computing for (s,i)= 5 65...equi done
# computing for (s,i)= 5 66...equi done
# computing for (s,i)= 5 67...equi done
# computing for (s,i)= 5 68...equi done
# computing for (s,i)= 5 69...equi done
# computing for (s,i)= 5 70...equi done
# computing for (s,i)= 5 71...equi done
# computing for (s,i)= 5 72...equi done
# computing for (s,i)= 5 73...equi done
# computing for (s,i)= 5 74...equi done
# computing for (s,i)= 5 75...equi done
# computing for (s,i)= 5 76...equi done
# computing for (s,i)= 5 77...equi done
# computing for (s,i)= 5 78...equi done
# computing for (s,i)= 5 79...equi done
# computing for (s,i)= 5 80...equi done
# computing for (s,i)= 5 81...equi done
# computing for (s,i)= 5 82...equi done
# computing for (s,i)= 5 83...equi done
# computing for (s,i)= 5 84...equi done
# computing for (s,i)= 5 85...equi done
# computing for (s,i)= 5 86...equi done
# computing for (s,i)= 5 87...equi done
# computing for (s,i)= 5 88...equi done
# computing for (s,i)= 5 89...equi done
# computing for (s,i)= 5 90...equi done
# computing for (s,i)= 5 91...equi done
# computing for (s,i)= 5 92...equi done
# computing for (s,i)= 5 93...equi done
# computing for (s,i)= 5 94...equi done
# computing for (s,i)= 5 95...computing for (s,i)= 5 96...computing for (s,i)= 5 97...computing for (s,i)= 5 98...computing for (s,i)= 5 99...computing for (s,i)= 6 1...equi done
# computing for (s,i)= 6 2...equi done
# computing for (s,i)= 6 3...equi done
# computing for (s,i)= 6 4...equi done
# computing for (s,i)= 6 5...equi done
# computing for (s,i)= 6 6...equi done
# computing for (s,i)= 6 7...equi done
# computing for (s,i)= 6 8...equi done
# computing for (s,i)= 6 9...equi done
# computing for (s,i)= 6 10...equi done
# computing for (s,i)= 6 11...equi done
# computing for (s,i)= 6 12...equi done
# computing for (s,i)= 6 13...equi done
# computing for (s,i)= 6 14...equi done
# computing for (s,i)= 6 15...equi done
# computing for (s,i)= 6 16...equi done
# computing for (s,i)= 6 17...equi done
# computing for (s,i)= 6 18...equi done
# computing for (s,i)= 6 19...equi done
# computing for (s,i)= 6 20...equi done
# computing for (s,i)= 6 21...equi done
# computing for (s,i)= 6 22...equi done
# computing for (s,i)= 6 23...equi done
# computing for (s,i)= 6 24...equi done
# computing for (s,i)= 6 25...equi done
# computing for (s,i)= 6 26...equi done
# computing for (s,i)= 6 27...equi done
# computing for (s,i)= 6 28...equi done
# computing for (s,i)= 6 29...equi done
# computing for (s,i)= 6 30...equi done
# computing for (s,i)= 6 31...equi done
# computing for (s,i)= 6 32...equi done
# computing for (s,i)= 6 33...equi done
# computing for (s,i)= 6 34...equi done
# computing for (s,i)= 6 35...equi done
# computing for (s,i)= 6 36...equi done
# computing for (s,i)= 6 37...equi done
# computing for (s,i)= 6 38...equi done
# computing for (s,i)= 6 39...equi done
# computing for (s,i)= 6 40...equi done
# computing for (s,i)= 6 41...equi done
# computing for (s,i)= 6 42...equi done
# computing for (s,i)= 6 43...equi done
# computing for (s,i)= 6 44...equi done
# computing for (s,i)= 6 45...equi done
# computing for (s,i)= 6 46...equi done
# computing for (s,i)= 6 47...equi done
# computing for (s,i)= 6 48...equi done
# computing for (s,i)= 6 49...equi done
# computing for (s,i)= 6 50...equi done
# computing for (s,i)= 6 51...equi done
# computing for (s,i)= 6 52...equi done
# computing for (s,i)= 6 53...equi done
# computing for (s,i)= 6 54...equi done
# computing for (s,i)= 6 55...equi done
# computing for (s,i)= 6 56...equi done
# computing for (s,i)= 6 57...equi done
# computing for (s,i)= 6 58...equi done
# computing for (s,i)= 6 59...equi done
# computing for (s,i)= 6 60...equi done
# computing for (s,i)= 6 61...equi done
# computing for (s,i)= 6 62...equi done
# computing for (s,i)= 6 63...equi done
# computing for (s,i)= 6 64...equi done
# computing for (s,i)= 6 65...equi done
# computing for (s,i)= 6 66...equi done
# computing for (s,i)= 6 67...equi done
# computing for (s,i)= 6 68...equi done
# computing for (s,i)= 6 69...equi done
# computing for (s,i)= 6 70...equi done
# computing for (s,i)= 6 71...equi done
# computing for (s,i)= 6 72...equi done
# computing for (s,i)= 6 73...equi done
# computing for (s,i)= 6 74...equi done
# computing for (s,i)= 6 75...equi done
# computing for (s,i)= 6 76...equi done
# computing for (s,i)= 6 77...equi done
# computing for (s,i)= 6 78...equi done
# computing for (s,i)= 6 79...equi done
# computing for (s,i)= 6 80...equi done
# computing for (s,i)= 6 81...equi done
# computing for (s,i)= 6 82...equi done
# computing for (s,i)= 6 83...equi done
# computing for (s,i)= 6 84...equi done
# computing for (s,i)= 6 85...equi done
# computing for (s,i)= 6 86...equi done
# computing for (s,i)= 6 87...equi done
# computing for (s,i)= 6 88...equi done
# computing for (s,i)= 6 89...equi done
# computing for (s,i)= 6 90...equi done
# computing for (s,i)= 6 91...equi done
# computing for (s,i)= 6 92...equi done
# computing for (s,i)= 6 93...equi done
# computing for (s,i)= 6 94...computing for (s,i)= 6 95...computing for (s,i)= 6 96...computing for (s,i)= 6 97...computing for (s,i)= 6 98...computing for (s,i)= 6 99...computing for (s,i)= 7 1...equi done
# computing for (s,i)= 7 2...equi done
# computing for (s,i)= 7 3...equi done
# computing for (s,i)= 7 4...equi done
# computing for (s,i)= 7 5...equi done
# computing for (s,i)= 7 6...equi done
# computing for (s,i)= 7 7...equi done
# computing for (s,i)= 7 8...equi done
# computing for (s,i)= 7 9...equi done
# computing for (s,i)= 7 10...equi done
# computing for (s,i)= 7 11...equi done
# computing for (s,i)= 7 12...equi done
# computing for (s,i)= 7 13...equi done
# computing for (s,i)= 7 14...equi done
# computing for (s,i)= 7 15...equi done
# computing for (s,i)= 7 16...equi done
# computing for (s,i)= 7 17...equi done
# computing for (s,i)= 7 18...equi done
# computing for (s,i)= 7 19...equi done
# computing for (s,i)= 7 20...equi done
# computing for (s,i)= 7 21...equi done
# computing for (s,i)= 7 22...equi done
# computing for (s,i)= 7 23...equi done
# computing for (s,i)= 7 24...equi done
# computing for (s,i)= 7 25...equi done
# computing for (s,i)= 7 26...equi done
# computing for (s,i)= 7 27...equi done
# computing for (s,i)= 7 28...equi done
# computing for (s,i)= 7 29...equi done
# computing for (s,i)= 7 30...equi done
# computing for (s,i)= 7 31...equi done
# computing for (s,i)= 7 32...equi done
# computing for (s,i)= 7 33...equi done
# computing for (s,i)= 7 34...equi done
# computing for (s,i)= 7 35...equi done
# computing for (s,i)= 7 36...equi done
# computing for (s,i)= 7 37...equi done
# computing for (s,i)= 7 38...equi done
# computing for (s,i)= 7 39...equi done
# computing for (s,i)= 7 40...equi done
# computing for (s,i)= 7 41...equi done
# computing for (s,i)= 7 42...equi done
# computing for (s,i)= 7 43...equi done
# computing for (s,i)= 7 44...equi done
# computing for (s,i)= 7 45...equi done
# computing for (s,i)= 7 46...equi done
# computing for (s,i)= 7 47...equi done
# computing for (s,i)= 7 48...equi done
# computing for (s,i)= 7 49...equi done
# computing for (s,i)= 7 50...equi done
# computing for (s,i)= 7 51...equi done
# computing for (s,i)= 7 52...equi done
# computing for (s,i)= 7 53...equi done
# computing for (s,i)= 7 54...equi done
# computing for (s,i)= 7 55...equi done
# computing for (s,i)= 7 56...equi done
# computing for (s,i)= 7 57...equi done
# computing for (s,i)= 7 58...equi done
# computing for (s,i)= 7 59...equi done
# computing for (s,i)= 7 60...equi done
# computing for (s,i)= 7 61...equi done
# computing for (s,i)= 7 62...equi done
# computing for (s,i)= 7 63...equi done
# computing for (s,i)= 7 64...equi done
# computing for (s,i)= 7 65...equi done
# computing for (s,i)= 7 66...equi done
# computing for (s,i)= 7 67...equi done
# computing for (s,i)= 7 68...equi done
# computing for (s,i)= 7 69...equi done
# computing for (s,i)= 7 70...equi done
# computing for (s,i)= 7 71...equi done
# computing for (s,i)= 7 72...equi done
# computing for (s,i)= 7 73...equi done
# computing for (s,i)= 7 74...equi done
# computing for (s,i)= 7 75...equi done
# computing for (s,i)= 7 76...equi done
# computing for (s,i)= 7 77...equi done
# computing for (s,i)= 7 78...equi done
# computing for (s,i)= 7 79...equi done
# computing for (s,i)= 7 80...equi done
# computing for (s,i)= 7 81...equi done
# computing for (s,i)= 7 82...equi done
# computing for (s,i)= 7 83...equi done
# computing for (s,i)= 7 84...equi done
# computing for (s,i)= 7 85...equi done
# computing for (s,i)= 7 86...equi done
# computing for (s,i)= 7 87...equi done
# computing for (s,i)= 7 88...equi done
# computing for (s,i)= 7 89...equi done
# computing for (s,i)= 7 90...equi done
# computing for (s,i)= 7 91...equi done
# computing for (s,i)= 7 92...equi done
# computing for (s,i)= 7 93...computing for (s,i)= 7 94...computing for (s,i)= 7 95...computing for (s,i)= 7 96...computing for (s,i)= 7 97...computing for (s,i)= 7 98...computing for (s,i)= 7 99...computing for (s,i)= 8 1...equi done
# computing for (s,i)= 8 2...equi done
# computing for (s,i)= 8 3...equi done
# computing for (s,i)= 8 4...equi done
# computing for (s,i)= 8 5...equi done
# computing for (s,i)= 8 6...equi done
# computing for (s,i)= 8 7...equi done
# computing for (s,i)= 8 8...equi done
# computing for (s,i)= 8 9...equi done
# computing for (s,i)= 8 10...equi done
# computing for (s,i)= 8 11...equi done
# computing for (s,i)= 8 12...equi done
# computing for (s,i)= 8 13...equi done
# computing for (s,i)= 8 14...equi done
# computing for (s,i)= 8 15...equi done
# computing for (s,i)= 8 16...equi done
# computing for (s,i)= 8 17...equi done
# computing for (s,i)= 8 18...equi done
# computing for (s,i)= 8 19...equi done
# computing for (s,i)= 8 20...equi done
# computing for (s,i)= 8 21...equi done
# computing for (s,i)= 8 22...equi done
# computing for (s,i)= 8 23...equi done
# computing for (s,i)= 8 24...equi done
# computing for (s,i)= 8 25...equi done
# computing for (s,i)= 8 26...equi done
# computing for (s,i)= 8 27...equi done
# computing for (s,i)= 8 28...equi done
# computing for (s,i)= 8 29...equi done
# computing for (s,i)= 8 30...equi done
# computing for (s,i)= 8 31...equi done
# computing for (s,i)= 8 32...equi done
# computing for (s,i)= 8 33...equi done
# computing for (s,i)= 8 34...equi done
# computing for (s,i)= 8 35...equi done
# computing for (s,i)= 8 36...equi done
# computing for (s,i)= 8 37...equi done
# computing for (s,i)= 8 38...equi done
# computing for (s,i)= 8 39...equi done
# computing for (s,i)= 8 40...equi done
# computing for (s,i)= 8 41...equi done
# computing for (s,i)= 8 42...equi done
# computing for (s,i)= 8 43...equi done
# computing for (s,i)= 8 44...equi done
# computing for (s,i)= 8 45...equi done
# computing for (s,i)= 8 46...equi done
# computing for (s,i)= 8 47...equi done
# computing for (s,i)= 8 48...equi done
# computing for (s,i)= 8 49...equi done
# computing for (s,i)= 8 50...equi done
# computing for (s,i)= 8 51...equi done
# computing for (s,i)= 8 52...equi done
# computing for (s,i)= 8 53...equi done
# computing for (s,i)= 8 54...equi done
# computing for (s,i)= 8 55...equi done
# computing for (s,i)= 8 56...equi done
# computing for (s,i)= 8 57...equi done
# computing for (s,i)= 8 58...equi done
# computing for (s,i)= 8 59...equi done
# computing for (s,i)= 8 60...equi done
# computing for (s,i)= 8 61...equi done
# computing for (s,i)= 8 62...equi done
# computing for (s,i)= 8 63...equi done
# computing for (s,i)= 8 64...equi done
# computing for (s,i)= 8 65...equi done
# computing for (s,i)= 8 66...equi done
# computing for (s,i)= 8 67...equi done
# computing for (s,i)= 8 68...equi done
# computing for (s,i)= 8 69...equi done
# computing for (s,i)= 8 70...equi done
# computing for (s,i)= 8 71...equi done
# computing for (s,i)= 8 72...equi done
# computing for (s,i)= 8 73...equi done
# computing for (s,i)= 8 74...equi done
# computing for (s,i)= 8 75...equi done
# computing for (s,i)= 8 76...equi done
# computing for (s,i)= 8 77...equi done
# computing for (s,i)= 8 78...equi done
# computing for (s,i)= 8 79...equi done
# computing for (s,i)= 8 80...equi done
# computing for (s,i)= 8 81...equi done
# computing for (s,i)= 8 82...equi done
# computing for (s,i)= 8 83...equi done
# computing for (s,i)= 8 84...equi done
# computing for (s,i)= 8 85...equi done
# computing for (s,i)= 8 86...equi done
# computing for (s,i)= 8 87...equi done
# computing for (s,i)= 8 88...equi done
# computing for (s,i)= 8 89...equi done
# computing for (s,i)= 8 90...equi done
# computing for (s,i)= 8 91...equi done
# computing for (s,i)= 8 92...computing for (s,i)= 8 93...computing for (s,i)= 8 94...computing for (s,i)= 8 95...computing for (s,i)= 8 96...computing for (s,i)= 8 97...computing for (s,i)= 8 98...computing for (s,i)= 8 99...computing for (s,i)= 9 1...equi done
# computing for (s,i)= 9 2...equi done
# computing for (s,i)= 9 3...equi done
# computing for (s,i)= 9 4...equi done
# computing for (s,i)= 9 5...equi done
# computing for (s,i)= 9 6...equi done
# computing for (s,i)= 9 7...equi done
# computing for (s,i)= 9 8...equi done
# computing for (s,i)= 9 9...equi done
# computing for (s,i)= 9 10...equi done
# computing for (s,i)= 9 11...equi done
# computing for (s,i)= 9 12...equi done
# computing for (s,i)= 9 13...equi done
# computing for (s,i)= 9 14...equi done
# computing for (s,i)= 9 15...equi done
# computing for (s,i)= 9 16...equi done
# computing for (s,i)= 9 17...equi done
# computing for (s,i)= 9 18...equi done
# computing for (s,i)= 9 19...equi done
# computing for (s,i)= 9 20...equi done
# computing for (s,i)= 9 21...equi done
# computing for (s,i)= 9 22...equi done
# computing for (s,i)= 9 23...equi done
# computing for (s,i)= 9 24...equi done
# computing for (s,i)= 9 25...equi done
# computing for (s,i)= 9 26...equi done
# computing for (s,i)= 9 27...equi done
# computing for (s,i)= 9 28...equi done
# computing for (s,i)= 9 29...equi done
# computing for (s,i)= 9 30...equi done
# computing for (s,i)= 9 31...equi done
# computing for (s,i)= 9 32...equi done
# computing for (s,i)= 9 33...equi done
# computing for (s,i)= 9 34...equi done
# computing for (s,i)= 9 35...equi done
# computing for (s,i)= 9 36...equi done
# computing for (s,i)= 9 37...equi done
# computing for (s,i)= 9 38...equi done
# computing for (s,i)= 9 39...equi done
# computing for (s,i)= 9 40...equi done
# computing for (s,i)= 9 41...equi done
# computing for (s,i)= 9 42...equi done
# computing for (s,i)= 9 43...equi done
# computing for (s,i)= 9 44...equi done
# computing for (s,i)= 9 45...equi done
# computing for (s,i)= 9 46...equi done
# computing for (s,i)= 9 47...equi done
# computing for (s,i)= 9 48...equi done
# computing for (s,i)= 9 49...equi done
# computing for (s,i)= 9 50...equi done
# computing for (s,i)= 9 51...equi done
# computing for (s,i)= 9 52...equi done
# computing for (s,i)= 9 53...equi done
# computing for (s,i)= 9 54...equi done
# computing for (s,i)= 9 55...equi done
# computing for (s,i)= 9 56...equi done
# computing for (s,i)= 9 57...equi done
# computing for (s,i)= 9 58...equi done
# computing for (s,i)= 9 59...equi done
# computing for (s,i)= 9 60...equi done
# computing for (s,i)= 9 61...equi done
# computing for (s,i)= 9 62...equi done
# computing for (s,i)= 9 63...equi done
# computing for (s,i)= 9 64...equi done
# computing for (s,i)= 9 65...equi done
# computing for (s,i)= 9 66...equi done
# computing for (s,i)= 9 67...equi done
# computing for (s,i)= 9 68...equi done
# computing for (s,i)= 9 69...equi done
# computing for (s,i)= 9 70...equi done
# computing for (s,i)= 9 71...equi done
# computing for (s,i)= 9 72...equi done
# computing for (s,i)= 9 73...equi done
# computing for (s,i)= 9 74...equi done
# computing for (s,i)= 9 75...equi done
# computing for (s,i)= 9 76...equi done
# computing for (s,i)= 9 77...equi done
# computing for (s,i)= 9 78...equi done
# computing for (s,i)= 9 79...equi done
# computing for (s,i)= 9 80...equi done
# computing for (s,i)= 9 81...equi done
# computing for (s,i)= 9 82...equi done
# computing for (s,i)= 9 83...equi done
# computing for (s,i)= 9 84...equi done
# computing for (s,i)= 9 85...equi done
# computing for (s,i)= 9 86...equi done
# computing for (s,i)= 9 87...equi done
# computing for (s,i)= 9 88...equi done
# computing for (s,i)= 9 89...equi done
# computing for (s,i)= 9 90...equi done
# computing for (s,i)= 9 91...computing for (s,i)= 9 92...computing for (s,i)= 9 93...computing for (s,i)= 9 94...computing for (s,i)= 9 95...computing for (s,i)= 9 96...computing for (s,i)= 9 97...computing for (s,i)= 9 98...computing for (s,i)= 9 99...computing for (s,i)= 10 1...equi done
# computing for (s,i)= 10 2...equi done
# computing for (s,i)= 10 3...equi done
# computing for (s,i)= 10 4...equi done
# computing for (s,i)= 10 5...equi done
# computing for (s,i)= 10 6...equi done
# computing for (s,i)= 10 7...equi done
# computing for (s,i)= 10 8...equi done
# computing for (s,i)= 10 9...equi done
# computing for (s,i)= 10 10...equi done
# computing for (s,i)= 10 11...equi done
# computing for (s,i)= 10 12...equi done
# computing for (s,i)= 10 13...equi done
# computing for (s,i)= 10 14...equi done
# computing for (s,i)= 10 15...equi done
# computing for (s,i)= 10 16...equi done
# computing for (s,i)= 10 17...equi done
# computing for (s,i)= 10 18...equi done
# computing for (s,i)= 10 19...equi done
# computing for (s,i)= 10 20...equi done
# computing for (s,i)= 10 21...equi done
# computing for (s,i)= 10 22...equi done
# computing for (s,i)= 10 23...equi done
# computing for (s,i)= 10 24...equi done
# computing for (s,i)= 10 25...equi done
# computing for (s,i)= 10 26...equi done
# computing for (s,i)= 10 27...equi done
# computing for (s,i)= 10 28...equi done
# computing for (s,i)= 10 29...equi done
# computing for (s,i)= 10 30...equi done
# computing for (s,i)= 10 31...equi done
# computing for (s,i)= 10 32...equi done
# computing for (s,i)= 10 33...equi done
# computing for (s,i)= 10 34...equi done
# computing for (s,i)= 10 35...equi done
# computing for (s,i)= 10 36...equi done
# computing for (s,i)= 10 37...equi done
# computing for (s,i)= 10 38...equi done
# computing for (s,i)= 10 39...equi done
# computing for (s,i)= 10 40...equi done
# computing for (s,i)= 10 41...equi done
# computing for (s,i)= 10 42...equi done
# computing for (s,i)= 10 43...equi done
# computing for (s,i)= 10 44...equi done
# computing for (s,i)= 10 45...equi done
# computing for (s,i)= 10 46...equi done
# computing for (s,i)= 10 47...equi done
# computing for (s,i)= 10 48...equi done
# computing for (s,i)= 10 49...equi done
# computing for (s,i)= 10 50...equi done
# computing for (s,i)= 10 51...equi done
# computing for (s,i)= 10 52...equi done
# computing for (s,i)= 10 53...equi done
# computing for (s,i)= 10 54...equi done
# computing for (s,i)= 10 55...equi done
# computing for (s,i)= 10 56...equi done
# computing for (s,i)= 10 57...equi done
# computing for (s,i)= 10 58...equi done
# computing for (s,i)= 10 59...equi done
# computing for (s,i)= 10 60...equi done
# computing for (s,i)= 10 61...equi done
# computing for (s,i)= 10 62...equi done
# computing for (s,i)= 10 63...equi done
# computing for (s,i)= 10 64...equi done
# computing for (s,i)= 10 65...equi done
# computing for (s,i)= 10 66...equi done
# computing for (s,i)= 10 67...equi done
# computing for (s,i)= 10 68...equi done
# computing for (s,i)= 10 69...equi done
# computing for (s,i)= 10 70...equi done
# computing for (s,i)= 10 71...equi done
# computing for (s,i)= 10 72...equi done
# computing for (s,i)= 10 73...equi done
# computing for (s,i)= 10 74...equi done
# computing for (s,i)= 10 75...equi done
# computing for (s,i)= 10 76...equi done
# computing for (s,i)= 10 77...equi done
# computing for (s,i)= 10 78...equi done
# computing for (s,i)= 10 79...equi done
# computing for (s,i)= 10 80...equi done
# computing for (s,i)= 10 81...equi done
# computing for (s,i)= 10 82...equi done
# computing for (s,i)= 10 83...equi done
# computing for (s,i)= 10 84...equi done
# computing for (s,i)= 10 85...equi done
# computing for (s,i)= 10 86...equi done
# computing for (s,i)= 10 87...equi done
# computing for (s,i)= 10 88...equi done
# computing for (s,i)= 10 89...equi done
# computing for (s,i)= 10 90...computing for (s,i)= 10 91...computing for (s,i)= 10 92...computing for (s,i)= 10 93...computing for (s,i)= 10 94...computing for (s,i)= 10 95...computing for (s,i)= 10 96...computing for (s,i)= 10 97...computing for (s,i)= 10 98...computing for (s,i)= 10 99...computing for (s,i)= 11 1...equi done
# computing for (s,i)= 11 2...equi done
# computing for (s,i)= 11 3...equi done
# computing for (s,i)= 11 4...equi done
# computing for (s,i)= 11 5...equi done
# computing for (s,i)= 11 6...equi done
# computing for (s,i)= 11 7...equi done
# computing for (s,i)= 11 8...equi done
# computing for (s,i)= 11 9...equi done
# computing for (s,i)= 11 10...equi done
# computing for (s,i)= 11 11...equi done
# computing for (s,i)= 11 12...equi done
# computing for (s,i)= 11 13...equi done
# computing for (s,i)= 11 14...equi done
# computing for (s,i)= 11 15...equi done
# computing for (s,i)= 11 16...equi done
# computing for (s,i)= 11 17...equi done
# computing for (s,i)= 11 18...equi done
# computing for (s,i)= 11 19...equi done
# computing for (s,i)= 11 20...equi done
# computing for (s,i)= 11 21...equi done
# computing for (s,i)= 11 22...equi done
# computing for (s,i)= 11 23...equi done
# computing for (s,i)= 11 24...equi done
# computing for (s,i)= 11 25...equi done
# computing for (s,i)= 11 26...equi done
# computing for (s,i)= 11 27...equi done
# computing for (s,i)= 11 28...equi done
# computing for (s,i)= 11 29...equi done
# computing for (s,i)= 11 30...equi done
# computing for (s,i)= 11 31...equi done
# computing for (s,i)= 11 32...equi done
# computing for (s,i)= 11 33...equi done
# computing for (s,i)= 11 34...equi done
# computing for (s,i)= 11 35...equi done
# computing for (s,i)= 11 36...equi done
# computing for (s,i)= 11 37...equi done
# computing for (s,i)= 11 38...equi done
# computing for (s,i)= 11 39...equi done
# computing for (s,i)= 11 40...equi done
# computing for (s,i)= 11 41...equi done
# computing for (s,i)= 11 42...equi done
# computing for (s,i)= 11 43...equi done
# computing for (s,i)= 11 44...equi done
# computing for (s,i)= 11 45...equi done
# computing for (s,i)= 11 46...equi done
# computing for (s,i)= 11 47...equi done
# computing for (s,i)= 11 48...equi done
# computing for (s,i)= 11 49...equi done
# computing for (s,i)= 11 50...equi done
# computing for (s,i)= 11 51...equi done
# computing for (s,i)= 11 52...equi done
# computing for (s,i)= 11 53...equi done
# computing for (s,i)= 11 54...equi done
# computing for (s,i)= 11 55...equi done
# computing for (s,i)= 11 56...equi done
# computing for (s,i)= 11 57...equi done
# computing for (s,i)= 11 58...equi done
# computing for (s,i)= 11 59...equi done
# computing for (s,i)= 11 60...equi done
# computing for (s,i)= 11 61...equi done
# computing for (s,i)= 11 62...equi done
# computing for (s,i)= 11 63...equi done
# computing for (s,i)= 11 64...equi done
# computing for (s,i)= 11 65...equi done
# computing for (s,i)= 11 66...equi done
# computing for (s,i)= 11 67...equi done
# computing for (s,i)= 11 68...equi done
# computing for (s,i)= 11 69...equi done
# computing for (s,i)= 11 70...equi done
# computing for (s,i)= 11 71...equi done
# computing for (s,i)= 11 72...equi done
# computing for (s,i)= 11 73...equi done
# computing for (s,i)= 11 74...equi done
# computing for (s,i)= 11 75...equi done
# computing for (s,i)= 11 76...equi done
# computing for (s,i)= 11 77...equi done
# computing for (s,i)= 11 78...equi done
# computing for (s,i)= 11 79...equi done
# computing for (s,i)= 11 80...equi done
# computing for (s,i)= 11 81...equi done
# computing for (s,i)= 11 82...equi done
# computing for (s,i)= 11 83...equi done
# computing for (s,i)= 11 84...equi done
# computing for (s,i)= 11 85...equi done
# computing for (s,i)= 11 86...equi done
# computing for (s,i)= 11 87...equi done
# computing for (s,i)= 11 88...equi done
# computing for (s,i)= 11 89...computing for (s,i)= 11 90...computing for (s,i)= 11 91...computing for (s,i)= 11 92...computing for (s,i)= 11 93...computing for (s,i)= 11 94...computing for (s,i)= 11 95...computing for (s,i)= 11 96...computing for (s,i)= 11 97...computing for (s,i)= 11 98...computing for (s,i)= 11 99...computing for (s,i)= 12 1...equi done
# computing for (s,i)= 12 2...equi done
# computing for (s,i)= 12 3...equi done
# computing for (s,i)= 12 4...equi done
# computing for (s,i)= 12 5...equi done
# computing for (s,i)= 12 6...equi done
# computing for (s,i)= 12 7...equi done
# computing for (s,i)= 12 8...equi done
# computing for (s,i)= 12 9...equi done
# computing for (s,i)= 12 10...equi done
# computing for (s,i)= 12 11...equi done
# computing for (s,i)= 12 12...equi done
# computing for (s,i)= 12 13...equi done
# computing for (s,i)= 12 14...equi done
# computing for (s,i)= 12 15...equi done
# computing for (s,i)= 12 16...equi done
# computing for (s,i)= 12 17...equi done
# computing for (s,i)= 12 18...equi done
# computing for (s,i)= 12 19...equi done
# computing for (s,i)= 12 20...equi done
# computing for (s,i)= 12 21...equi done
# computing for (s,i)= 12 22...equi done
# computing for (s,i)= 12 23...equi done
# computing for (s,i)= 12 24...equi done
# computing for (s,i)= 12 25...equi done
# computing for (s,i)= 12 26...equi done
# computing for (s,i)= 12 27...equi done
# computing for (s,i)= 12 28...equi done
# computing for (s,i)= 12 29...equi done
# computing for (s,i)= 12 30...equi done
# computing for (s,i)= 12 31...equi done
# computing for (s,i)= 12 32...equi done
# computing for (s,i)= 12 33...equi done
# computing for (s,i)= 12 34...equi done
# computing for (s,i)= 12 35...equi done
# computing for (s,i)= 12 36...equi done
# computing for (s,i)= 12 37...equi done
# computing for (s,i)= 12 38...equi done
# computing for (s,i)= 12 39...equi done
# computing for (s,i)= 12 40...equi done
# computing for (s,i)= 12 41...equi done
# computing for (s,i)= 12 42...equi done
# computing for (s,i)= 12 43...equi done
# computing for (s,i)= 12 44...equi done
# computing for (s,i)= 12 45...equi done
# computing for (s,i)= 12 46...equi done
# computing for (s,i)= 12 47...equi done
# computing for (s,i)= 12 48...equi done
# computing for (s,i)= 12 49...equi done
# computing for (s,i)= 12 50...equi done
# computing for (s,i)= 12 51...equi done
# computing for (s,i)= 12 52...equi done
# computing for (s,i)= 12 53...equi done
# computing for (s,i)= 12 54...equi done
# computing for (s,i)= 12 55...equi done
# computing for (s,i)= 12 56...equi done
# computing for (s,i)= 12 57...equi done
# computing for (s,i)= 12 58...equi done
# computing for (s,i)= 12 59...equi done
# computing for (s,i)= 12 60...equi done
# computing for (s,i)= 12 61...equi done
# computing for (s,i)= 12 62...equi done
# computing for (s,i)= 12 63...equi done
# computing for (s,i)= 12 64...equi done
# computing for (s,i)= 12 65...equi done
# computing for (s,i)= 12 66...equi done
# computing for (s,i)= 12 67...equi done
# computing for (s,i)= 12 68...equi done
# computing for (s,i)= 12 69...equi done
# computing for (s,i)= 12 70...equi done
# computing for (s,i)= 12 71...equi done
# computing for (s,i)= 12 72...equi done
# computing for (s,i)= 12 73...equi done
# computing for (s,i)= 12 74...equi done
# computing for (s,i)= 12 75...equi done
# computing for (s,i)= 12 76...equi done
# computing for (s,i)= 12 77...equi done
# computing for (s,i)= 12 78...equi done
# computing for (s,i)= 12 79...equi done
# computing for (s,i)= 12 80...equi done
# computing for (s,i)= 12 81...equi done
# computing for (s,i)= 12 82...equi done
# computing for (s,i)= 12 83...equi done
# computing for (s,i)= 12 84...equi done
# computing for (s,i)= 12 85...equi done
# computing for (s,i)= 12 86...equi done
# computing for (s,i)= 12 87...equi done
# computing for (s,i)= 12 88...computing for (s,i)= 12 89...computing for (s,i)= 12 90...computing for (s,i)= 12 91...computing for (s,i)= 12 92...computing for (s,i)= 12 93...computing for (s,i)= 12 94...computing for (s,i)= 12 95...computing for (s,i)= 12 96...computing for (s,i)= 12 97...computing for (s,i)= 12 98...computing for (s,i)= 12 99...computing for (s,i)= 13 1...equi done
# computing for (s,i)= 13 2...equi done
# computing for (s,i)= 13 3...equi done
# computing for (s,i)= 13 4...equi done
# computing for (s,i)= 13 5...equi done
# computing for (s,i)= 13 6...equi done
# computing for (s,i)= 13 7...equi done
# computing for (s,i)= 13 8...equi done
# computing for (s,i)= 13 9...equi done
# computing for (s,i)= 13 10...equi done
# computing for (s,i)= 13 11...equi done
# computing for (s,i)= 13 12...equi done
# computing for (s,i)= 13 13...equi done
# computing for (s,i)= 13 14...equi done
# computing for (s,i)= 13 15...equi done
# computing for (s,i)= 13 16...equi done
# computing for (s,i)= 13 17...equi done
# computing for (s,i)= 13 18...equi done
# computing for (s,i)= 13 19...equi done
# computing for (s,i)= 13 20...equi done
# computing for (s,i)= 13 21...equi done
# computing for (s,i)= 13 22...equi done
# computing for (s,i)= 13 23...equi done
# computing for (s,i)= 13 24...equi done
# computing for (s,i)= 13 25...equi done
# computing for (s,i)= 13 26...equi done
# computing for (s,i)= 13 27...equi done
# computing for (s,i)= 13 28...equi done
# computing for (s,i)= 13 29...equi done
# computing for (s,i)= 13 30...equi done
# computing for (s,i)= 13 31...equi done
# computing for (s,i)= 13 32...equi done
# computing for (s,i)= 13 33...equi done
# computing for (s,i)= 13 34...equi done
# computing for (s,i)= 13 35...equi done
# computing for (s,i)= 13 36...equi done
# computing for (s,i)= 13 37...equi done
# computing for (s,i)= 13 38...equi done
# computing for (s,i)= 13 39...equi done
# computing for (s,i)= 13 40...equi done
# computing for (s,i)= 13 41...equi done
# computing for (s,i)= 13 42...equi done
# computing for (s,i)= 13 43...equi done
# computing for (s,i)= 13 44...equi done
# computing for (s,i)= 13 45...equi done
# computing for (s,i)= 13 46...equi done
# computing for (s,i)= 13 47...equi done
# computing for (s,i)= 13 48...equi done
# computing for (s,i)= 13 49...equi done
# computing for (s,i)= 13 50...equi done
# computing for (s,i)= 13 51...equi done
# computing for (s,i)= 13 52...equi done
# computing for (s,i)= 13 53...equi done
# computing for (s,i)= 13 54...equi done
# computing for (s,i)= 13 55...equi done
# computing for (s,i)= 13 56...equi done
# computing for (s,i)= 13 57...equi done
# computing for (s,i)= 13 58...equi done
# computing for (s,i)= 13 59...equi done
# computing for (s,i)= 13 60...equi done
# computing for (s,i)= 13 61...equi done
# computing for (s,i)= 13 62...equi done
# computing for (s,i)= 13 63...equi done
# computing for (s,i)= 13 64...equi done
# computing for (s,i)= 13 65...equi done
# computing for (s,i)= 13 66...equi done
# computing for (s,i)= 13 67...equi done
# computing for (s,i)= 13 68...equi done
# computing for (s,i)= 13 69...equi done
# computing for (s,i)= 13 70...equi done
# computing for (s,i)= 13 71...equi done
# computing for (s,i)= 13 72...equi done
# computing for (s,i)= 13 73...equi done
# computing for (s,i)= 13 74...equi done
# computing for (s,i)= 13 75...equi done
# computing for (s,i)= 13 76...equi done
# computing for (s,i)= 13 77...equi done
# computing for (s,i)= 13 78...equi done
# computing for (s,i)= 13 79...equi done
# computing for (s,i)= 13 80...equi done
# computing for (s,i)= 13 81...equi done
# computing for (s,i)= 13 82...equi done
# computing for (s,i)= 13 83...equi done
# computing for (s,i)= 13 84...equi done
# computing for (s,i)= 13 85...equi done
# computing for (s,i)= 13 86...equi done
# ...
# computing for (s,i)= 19 38...equi done
# computing for (s,i)= 19 39...equi done
# computing for (s,i)= 19 40...equi done
# computing for (s,i)= 19 41...equi done
# computing for (s,i)= 19 42...equi done
# computing for (s,i)= 19 43...equi done
# computing for (s,i)= 19 44...equi done
# computing for (s,i)= 19 45...equi done
# computing for (s,i)= 19 46...equi done
# computing for (s,i)= 19 47...equi done
# computing for (s,i)= 19 48...equi done
# computing for (s,i)= 19 49...equi done
# computing for (s,i)= 19 50...equi done
# computing for (s,i)= 19 51...equi done
# computing for (s,i)= 19 52...equi done
# computing for (s,i)= 19 53...equi done
# computing for (s,i)= 19 54...equi done
# computing for (s,i)= 19 55...equi done
# computing for (s,i)= 19 56...equi done
# computing for (s,i)= 19 57...equi done
# computing for (s,i)= 19 58...equi done
# computing for (s,i)= 19 59...equi done
# computing for (s,i)= 19 60...equi done
# computing for (s,i)= 19 61...equi done
# computing for (s,i)= 19 62...equi done
# computing for (s,i)= 19 63...equi done
# computing for (s,i)= 19 64...equi done
# computing for (s,i)= 19 65...equi done
# computing for (s,i)= 19 66...equi done
# computing for (s,i)= 19 67...equi done
# computing for (s,i)= 19 68...equi done
# computing for (s,i)= 19 69...equi done
# computing for (s,i)= 19 70...equi done
# computing for (s,i)= 19 71...equi done
# computing for (s,i)= 19 72...equi done
# computing for (s,i)= 19 73...equi done
# computing for (s,i)= 19 74...equi done
# computing for (s,i)= 19 75...equi done
# computing for (s,i)= 19 76...equi done
# computing for (s,i)= 19 77...equi done
# computing for (s,i)= 19 78...equi done
# computing for (s,i)= 19 79...equi done
# computing for (s,i)= 19 80...equi done
# computing for (s,i)= 19 81...computing for (s,i)= 19 82...computing for (s,i)= 19 83...computing for (s,i)= 19 84...computing for (s,i)= 19 85...computing for (s,i)= 19 86...computing for (s,i)= 19 87...computing for (s,i)= 19 88...computing for (s,i)= 19 89...computing for (s,i)= 19 90...computing for (s,i)= 19 91...computing for (s,i)= 19 92...computing for (s,i)= 19 93...computing for (s,i)= 19 94...computing for (s,i)= 19 95...computing for (s,i)= 19 96...computing for (s,i)= 19 97...computing for (s,i)= 19 98...computing for (s,i)= 19 99...computing for (s,i)= 20 1...equi done
# computing for (s,i)= 20 2...equi done
# computing for (s,i)= 20 3...equi done
# computing for (s,i)= 20 4...equi done
# computing for (s,i)= 20 5...equi done
# computing for (s,i)= 20 6...equi done
# computing for (s,i)= 20 7...equi done
# computing for (s,i)= 20 8...equi done
# computing for (s,i)= 20 9...equi done
# computing for (s,i)= 20 10...equi done
# computing for (s,i)= 20 11...equi done
# computing for (s,i)= 20 12...equi done
# computing for (s,i)= 20 13...equi done
# computing for (s,i)= 20 14...equi done
# computing for (s,i)= 20 15...equi done
# computing for (s,i)= 20 16...equi done
# computing for (s,i)= 20 17...equi done
# computing for (s,i)= 20 18...equi done
# computing for (s,i)= 20 19...equi done
# computing for (s,i)= 20 20...equi done
# computing for (s,i)= 20 21...equi done
# computing for (s,i)= 20 22...equi done
# computing for (s,i)= 20 23...equi done
# computing for (s,i)= 20 24...equi done
# computing for (s,i)= 20 25...equi done
# computing for (s,i)= 20 26...equi done
# computing for (s,i)= 20 27...equi done
# computing for (s,i)= 20 28...equi done
# computing for (s,i)= 20 29...equi done
# computing for (s,i)= 20 30...equi done
# computing for (s,i)= 20 31...equi done
# computing for (s,i)= 20 32...equi done
# computing for (s,i)= 20 33...equi done
# computing for (s,i)= 20 34...equi done
# computing for (s,i)= 20 35...equi done
# computing for (s,i)= 20 36...equi done
# computing for (s,i)= 20 37...equi done
# computing for (s,i)= 20 38...equi done
# computing for (s,i)= 20 39...equi done
# computing for (s,i)= 20 40...equi done
# computing for (s,i)= 20 41...equi done
# computing for (s,i)= 20 42...equi done
# computing for (s,i)= 20 43...equi done
# computing for (s,i)= 20 44...equi done
# computing for (s,i)= 20 45...equi done
# computing for (s,i)= 20 46...equi done
# computing for (s,i)= 20 47...equi done
# computing for (s,i)= 20 48...equi done
# computing for (s,i)= 20 49...equi done
# computing for (s,i)= 20 50...equi done
# computing for (s,i)= 20 51...equi done
# computing for (s,i)= 20 52...equi done
# computing for (s,i)= 20 53...equi done
# computing for (s,i)= 20 54...equi done
# computing for (s,i)= 20 55...equi done
# computing for (s,i)= 20 56...equi done
# computing for (s,i)= 20 57...equi done
# computing for (s,i)= 20 58...equi done
# computing for (s,i)= 20 59...equi done
# computing for (s,i)= 20 60...equi done
# computing for (s,i)= 20 61...equi done
# computing for (s,i)= 20 62...equi done
# computing for (s,i)= 20 63...equi done
# computing for (s,i)= 20 64...equi done
# computing for (s,i)= 20 65...equi done
# computing for (s,i)= 20 66...equi done
# computing for (s,i)= 20 67...equi done
# computing for (s,i)= 20 68...equi done
# computing for (s,i)= 20 69...equi done
# computing for (s,i)= 20 70...equi done
# computing for (s,i)= 20 71...equi done
# computing for (s,i)= 20 72...equi done
# computing for (s,i)= 20 73...equi done
# computing for (s,i)= 20 74...equi done
# computing for (s,i)= 20 75...equi done
# computing for (s,i)= 20 76...equi done
# computing for (s,i)= 20 77...equi done
# computing for (s,i)= 20 78...equi done
# computing for (s,i)= 20 79...equi done
# computing for (s,i)= 20 80...computing for (s,i)= 20 81...computing for (s,i)= 20 82...computing for (s,i)= 20 83...computing for (s,i)= 20 84...computing for (s,i)= 20 85...computing for (s,i)= 20 86...computing for (s,i)= 20 87...computing for (s,i)= 20 88...computing for (s,i)= 20 89...computing for (s,i)= 20 90...computing for (s,i)= 20 91...computing for (s,i)= 20 92...computing for (s,i)= 20 93...computing for (s,i)= 20 94...computing for (s,i)= 20 95...computing for (s,i)= 20 96...computing for (s,i)= 20 97...computing for (s,i)= 20 98...computing for (s,i)= 20 99...computing for (s,i)= 21 1...equi done
# computing for (s,i)= 21 2...equi done
# computing for (s,i)= 21 3...equi done
# computing for (s,i)= 21 4...equi done
# computing for (s,i)= 21 5...equi done
# computing for (s,i)= 21 6...equi done
# computing for (s,i)= 21 7...equi done
# computing for (s,i)= 21 8...equi done
# computing for (s,i)= 21 9...equi done
# computing for (s,i)= 21 10...equi done
# computing for (s,i)= 21 11...equi done
# computing for (s,i)= 21 12...equi done
# computing for (s,i)= 21 13...equi done
# computing for (s,i)= 21 14...equi done
# computing for (s,i)= 21 15...equi done
# computing for (s,i)= 21 16...equi done
# computing for (s,i)= 21 17...equi done
# computing for (s,i)= 21 18...equi done
# computing for (s,i)= 21 19...equi done
# computing for (s,i)= 21 20...equi done
# computing for (s,i)= 21 21...equi done
# computing for (s,i)= 21 22...equi done
# computing for (s,i)= 21 23...equi done
# computing for (s,i)= 21 24...equi done
# computing for (s,i)= 21 25...equi done
# computing for (s,i)= 21 26...equi done
# computing for (s,i)= 21 27...equi done
# computing for (s,i)= 21 28...equi done
# computing for (s,i)= 21 29...equi done
# computing for (s,i)= 21 30...equi done
# computing for (s,i)= 21 31...equi done
# computing for (s,i)= 21 32...equi done
# computing for (s,i)= 21 33...equi done
# computing for (s,i)= 21 34...equi done
# computing for (s,i)= 21 35...equi done
# computing for (s,i)= 21 36...equi done
# computing for (s,i)= 21 37...equi done
# computing for (s,i)= 21 38...equi done
# computing for (s,i)= 21 39...equi done
# computing for (s,i)= 21 40...equi done
# computing for (s,i)= 21 41...equi done
# computing for (s,i)= 21 42...equi done
# computing for (s,i)= 21 43...equi done
# computing for (s,i)= 21 44...equi done
# computing for (s,i)= 21 45...equi done
# computing for (s,i)= 21 46...equi done
# computing for (s,i)= 21 47...equi done
# computing for (s,i)= 21 48...equi done
# computing for (s,i)= 21 49...equi done
# computing for (s,i)= 21 50...equi done
# computing for (s,i)= 21 51...equi done
# computing for (s,i)= 21 52...equi done
# computing for (s,i)= 21 53...equi done
# computing for (s,i)= 21 54...equi done
# computing for (s,i)= 21 55...equi done
# computing for (s,i)= 21 56...equi done
# computing for (s,i)= 21 57...equi done
# computing for (s,i)= 21 58...equi done
# computing for (s,i)= 21 59...equi done
# computing for (s,i)= 21 60...equi done
# computing for (s,i)= 21 61...equi done
# computing for (s,i)= 21 62...equi done
# computing for (s,i)= 21 63...equi done
# computing for (s,i)= 21 64...equi done
# computing for (s,i)= 21 65...equi done
# computing for (s,i)= 21 66...equi done
# computing for (s,i)= 21 67...equi done
# computing for (s,i)= 21 68...equi done
# computing for (s,i)= 21 69...equi done
# computing for (s,i)= 21 70...equi done
# computing for (s,i)= 21 71...equi done
# computing for (s,i)= 21 72...equi done
# computing for (s,i)= 21 73...equi done
# computing for (s,i)= 21 74...equi done
# computing for (s,i)= 21 75...equi done
# computing for (s,i)= 21 76...equi done
# computing for (s,i)= 21 77...equi done
# computing for (s,i)= 21 78...equi done
# computing for (s,i)= 21 79...computing for (s,i)= 21 80...computing for (s,i)= 21 81...computing for (s,i)= 21 82...computing for (s,i)= 21 83...computing for (s,i)= 21 84...computing for (s,i)= 21 85...computing for (s,i)= 21 86...computing for (s,i)= 21 87...computing for (s,i)= 21 88...computing for (s,i)= 21 89...computing for (s,i)= 21 90...computing for (s,i)= 21 91...computing for (s,i)= 21 92...computing for (s,i)= 21 93...computing for (s,i)= 21 94...computing for (s,i)= 21 95...computing for (s,i)= 21 96...computing for (s,i)= 21 97...computing for (s,i)= 21 98...computing for (s,i)= 21 99...computing for (s,i)= 22 1...equi done
# computing for (s,i)= 22 2...equi done
# computing for (s,i)= 22 3...equi done
# computing for (s,i)= 22 4...equi done
# computing for (s,i)= 22 5...equi done
# computing for (s,i)= 22 6...equi done
# computing for (s,i)= 22 7...equi done
# computing for (s,i)= 22 8...equi done
# computing for (s,i)= 22 9...equi done
# computing for (s,i)= 22 10...equi done
# computing for (s,i)= 22 11...equi done
# computing for (s,i)= 22 12...equi done
# computing for (s,i)= 22 13...equi done
# computing for (s,i)= 22 14...equi done
# computing for (s,i)= 22 15...equi done
# computing for (s,i)= 22 16...equi done
# computing for (s,i)= 22 17...equi done
# computing for (s,i)= 22 18...equi done
# computing for (s,i)= 22 19...equi done
# computing for (s,i)= 22 20...equi done
# computing for (s,i)= 22 21...equi done
# computing for (s,i)= 22 22...equi done
# computing for (s,i)= 22 23...equi done
# computing for (s,i)= 22 24...equi done
# computing for (s,i)= 22 25...equi done
# computing for (s,i)= 22 26...equi done
# computing for (s,i)= 22 27...equi done
# computing for (s,i)= 22 28...equi done
# computing for (s,i)= 22 29...equi done
# computing for (s,i)= 22 30...equi done
# computing for (s,i)= 22 31...equi done
# computing for (s,i)= 22 32...equi done
# computing for (s,i)= 22 33...equi done
# computing for (s,i)= 22 34...equi done
# computing for (s,i)= 22 35...equi done
# computing for (s,i)= 22 36...equi done
# computing for (s,i)= 22 37...equi done
# computing for (s,i)= 22 38...equi done
# computing for (s,i)= 22 39...equi done
# computing for (s,i)= 22 40...equi done
# computing for (s,i)= 22 41...equi done
# computing for (s,i)= 22 42...equi done
# computing for (s,i)= 22 43...equi done
# computing for (s,i)= 22 44...equi done
# computing for (s,i)= 22 45...equi done
# computing for (s,i)= 22 46...equi done
# computing for (s,i)= 22 47...equi done
# computing for (s,i)= 22 48...equi done
# computing for (s,i)= 22 49...equi done
# computing for (s,i)= 22 50...equi done
# computing for (s,i)= 22 51...equi done
# computing for (s,i)= 22 52...equi done
# computing for (s,i)= 22 53...equi done
# computing for (s,i)= 22 54...equi done
# computing for (s,i)= 22 55...equi done
# computing for (s,i)= 22 56...equi done
# computing for (s,i)= 22 57...equi done
# computing for (s,i)= 22 58...equi done
# computing for (s,i)= 22 59...equi done
# computing for (s,i)= 22 60...equi done
# computing for (s,i)= 22 61...equi done
# computing for (s,i)= 22 62...equi done
# computing for (s,i)= 22 63...equi done
# computing for (s,i)= 22 64...equi done
# computing for (s,i)= 22 65...equi done
# computing for (s,i)= 22 66...equi done
# computing for (s,i)= 22 67...equi done
# computing for (s,i)= 22 68...equi done
# computing for (s,i)= 22 69...equi done
# computing for (s,i)= 22 70...equi done
# computing for (s,i)= 22 71...equi done
# computing for (s,i)= 22 72...equi done
# computing for (s,i)= 22 73...equi done
# computing for (s,i)= 22 74...equi done
# computing for (s,i)= 22 75...equi done
# computing for (s,i)= 22 76...equi done
# computing for (s,i)= 22 77...equi done
# computing for (s,i)= 22 78...computing for (s,i)= 22 79...computing for (s,i)= 22 80...computing for (s,i)= 22 81...computing for (s,i)= 22 82...computing for (s,i)= 22 83...computing for (s,i)= 22 84...computing for (s,i)= 22 85...computing for (s,i)= 22 86...computing for (s,i)= 22 87...computing for (s,i)= 22 88...computing for (s,i)= 22 89...computing for (s,i)= 22 90...computing for (s,i)= 22 91...computing for (s,i)= 22 92...computing for (s,i)= 22 93...computing for (s,i)= 22 94...computing for (s,i)= 22 95...computing for (s,i)= 22 96...computing for (s,i)= 22 97...computing for (s,i)= 22 98...computing for (s,i)= 22 99...computing for (s,i)= 23 1...equi done
# computing for (s,i)= 23 2...equi done
# computing for (s,i)= 23 3...equi done
# computing for (s,i)= 23 4...equi done
# computing for (s,i)= 23 5...equi done
# computing for (s,i)= 23 6...equi done
# computing for (s,i)= 23 7...equi done
# computing for (s,i)= 23 8...equi done
# computing for (s,i)= 23 9...equi done
# computing for (s,i)= 23 10...equi done
# computing for (s,i)= 23 11...equi done
# computing for (s,i)= 23 12...equi done
# computing for (s,i)= 23 13...equi done
# computing for (s,i)= 23 14...equi done
# computing for (s,i)= 23 15...equi done
# computing for (s,i)= 23 16...equi done
# computing for (s,i)= 23 17...equi done
# computing for (s,i)= 23 18...equi done
# computing for (s,i)= 23 19...equi done
# computing for (s,i)= 23 20...equi done
# computing for (s,i)= 23 21...equi done
# computing for (s,i)= 23 22...equi done
# computing for (s,i)= 23 23...equi done
# computing for (s,i)= 23 24...equi done
# computing for (s,i)= 23 25...equi done
# computing for (s,i)= 23 26...equi done
# computing for (s,i)= 23 27...equi done
# computing for (s,i)= 23 28...equi done
# computing for (s,i)= 23 29...equi done
# computing for (s,i)= 23 30...equi done
# computing for (s,i)= 23 31...equi done
# computing for (s,i)= 23 32...equi done
# computing for (s,i)= 23 33...equi done
# computing for (s,i)= 23 34...equi done
# computing for (s,i)= 23 35...equi done
# computing for (s,i)= 23 36...equi done
# computing for (s,i)= 23 37...equi done
# computing for (s,i)= 23 38...equi done
# computing for (s,i)= 23 39...equi done
# computing for (s,i)= 23 40...equi done
# computing for (s,i)= 23 41...equi done
# computing for (s,i)= 23 42...equi done
# computing for (s,i)= 23 43...equi done
# computing for (s,i)= 23 44...equi done
# computing for (s,i)= 23 45...equi done
# computing for (s,i)= 23 46...equi done
# computing for (s,i)= 23 47...equi done
# computing for (s,i)= 23 48...equi done
# computing for (s,i)= 23 49...equi done
# computing for (s,i)= 23 50...equi done
# computing for (s,i)= 23 51...equi done
# computing for (s,i)= 23 52...equi done
# computing for (s,i)= 23 53...equi done
# computing for (s,i)= 23 54...equi done
# computing for (s,i)= 23 55...equi done
# computing for (s,i)= 23 56...equi done
# computing for (s,i)= 23 57...equi done
# computing for (s,i)= 23 58...equi done
# computing for (s,i)= 23 59...equi done
# computing for (s,i)= 23 60...equi done
# computing for (s,i)= 23 61...equi done
# computing for (s,i)= 23 62...equi done
# computing for (s,i)= 23 63...equi done
# computing for (s,i)= 23 64...equi done
# computing for (s,i)= 23 65...equi done
# computing for (s,i)= 23 66...equi done
# computing for (s,i)= 23 67...equi done
# computing for (s,i)= 23 68...equi done
# computing for (s,i)= 23 69...equi done
# computing for (s,i)= 23 70...equi done
# computing for (s,i)= 23 71...equi done
# computing for (s,i)= 23 72...equi done
# computing for (s,i)= 23 73...

# %% [raw]
# print(mat_mfe_cost)
